# %%
import pandas as pd
import numpy as np
import visuals as vd
# %matplotlib inline
from IPython.display import display
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("customers.csv")
data.drop(["Region", "Channel"], inplace= True, axis= 1)

# %%
print(*data.shape)
# Out:
# 440 6

# %%
display(data.describe())
# Out:
#                Fresh          Milk       Grocery        Frozen  \
# count     440.000000    440.000000    440.000000    440.000000
# mean    12000.297727   5796.265909   7951.277273   3071.931818
# std     12647.328865   7380.377175   9503.162829   4854.673333
# min         3.000000     55.000000      3.000000     25.000000
# 25%      3127.750000   1533.000000   2153.000000    742.250000
# 50%      8504.000000   3627.000000   4755.500000   1526.000000
# 75%     16933.750000   7190.250000  10655.750000   3554.250000
# max    112151.000000  73498.000000  92780.000000  60869.000000
#
#        Detergents_Paper  Delicatessen
# count        440.000000    440.000000
# mean        2881.493182   1524.870455
# std         4767.854448   2820.105937
# min            3.000000      3.000000
# 25%          256.750000    408.250000
# 50%          816.500000    965.500000
# 75%         3922.000000   1820.250000
# max        40827.000000  47943.000000

# %%
import seaborn as sns
cmap = sns.cubehelix_palette(light=1, as_cmap=True)
sns.heatmap(data.corr(), annot=True, cmap=cmap)

# %%
data['Milk'].hist()

# %%
plt.style.use('ggplot')

# %%
data.plot(subplots= True, figsize= (8, 12), sharey= True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x125917790>,
# ...
#       dtype=object)

# %%
data.plot.area()

# %%
data.plot()

# %%
indices = [9, 19, 29, 39, 49, 59, 69, 79, 89, 99, 109, 119, 129, 139, 149, 159]
samples = pd.DataFrame(data.loc[indices], columns= data.keys()).reset_index(drop= True)
samples
# Out:
#     Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0    6006  11093    18881    1159              7425          2098
# 1    7780   2495     9464     669              2518           501
# 2   43088   2100     2609    1200              1107           823
# 3   56159    555      902   10002               212          2916
# 4    4967  21412    28921    1798             13583          1163
# 5    6137   5360     8040     129              3084          1603
# 6    8352   2820     1293     779               656           144
# 7    1640   3259     3655     868              1202          1653
# 8   24904   3836     5330    3443               454          3178
# 9    9658   2182     1909    5639               215           323
# 10   1406  16729    28986     673               836             3
# 11   8258   2344     2147    3896               266           635
# 12  42312    926     1510    1718               410          1819
# ...

# %%
samples - np.around(data.mean())
# Out:
#       Fresh     Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0   -5994.0   5297.0  10930.0 -1913.0            4544.0         573.0
# 1   -4220.0  -3301.0   1513.0 -2403.0            -363.0       -1024.0
# 2   31088.0  -3696.0  -5342.0 -1872.0           -1774.0        -702.0
# 3   44159.0  -5241.0  -7049.0  6930.0           -2669.0        1391.0
# 4   -7033.0  15616.0  20970.0 -1274.0           10702.0        -362.0
# 5   -5863.0   -436.0     89.0 -2943.0             203.0          78.0
# 6   -3648.0  -2976.0  -6658.0 -2293.0           -2225.0       -1381.0
# 7  -10360.0  -2537.0  -4296.0 -2204.0           -1679.0         128.0
# 8   12904.0  -1960.0  -2621.0   371.0           -2427.0        1653.0
# 9   -2342.0  -3614.0  -6042.0  2567.0           -2666.0       -1202.0
# 10 -10594.0  10933.0  21035.0 -2399.0           -2045.0       -1522.0
# 11  -3742.0  -3452.0  -5804.0   824.0           -2615.0        -890.0
# ...

# %%
samples - np.around(data.median(), decimals=1)
# Out:
#       Fresh     Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0   -2498.0   7466.0  14125.5  -367.0            6608.5        1132.5
# 1    -724.0  -1132.0   4708.5  -857.0            1701.5        -464.5
# 2   34584.0  -1527.0  -2146.5  -326.0             290.5        -142.5
# 3   47655.0  -3072.0  -3853.5  8476.0            -604.5        1950.5
# 4   -3537.0  17785.0  24165.5   272.0           12766.5         197.5
# 5   -2367.0   1733.0   3284.5 -1397.0            2267.5         637.5
# 6    -152.0   -807.0  -3462.5  -747.0            -160.5        -821.5
# 7   -6864.0   -368.0  -1100.5  -658.0             385.5         687.5
# 8   16400.0    209.0    574.5  1917.0            -362.5        2212.5
# 9    1154.0  -1445.0  -2846.5  4113.0            -601.5        -642.5
# 10  -7098.0  13102.0  24230.5  -853.0              19.5        -962.5
# 11   -246.0  -1283.0  -2608.5  2370.0            -550.5        -330.5
# ...

# %%
new_data = data.drop(['Detergents_Paper'], axis = 1)

# %%
Y_train = data['Detergents_Paper']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(new_data, Y_train, test_size= 0.2, random_state=0)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor(random_state=0)
dt.fit(X_train,y_train)
pd.DataFrame(dt.predict(X_test))
# Out:
#           0
# 0     821.0
# 1    7883.0
# 2    1580.0
# 3    7558.0
# 4     118.0
# ..      ...
# 83    483.0
# 84  14235.0
# 85   1777.0
# 86   3620.0
# 87    415.0
#
# [88 rows x 1 columns]

# %%
print(dt.score(X_test,y_test))
# Out:
# 0.7275787916887393

# %%
pd.plotting.scatter_matrix(data, diagonal='kde', figsize= (14, 8), alpha= 0.3)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x13379b290>,
# ...
#       dtype=object)

# %%
g = sns.PairGrid(data)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
